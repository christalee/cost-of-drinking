# %%
import pandas as pd

# %%
db_beer = pd.read_csv('data/beer-in-a-neighbourhood-pub.csv')
db_beer.set_index('canonical city')
# Out:
#                 price               country                region  latitude  \
# canonical city
# Dubai            11.4  United Arab Emirates          Middle east    25.2697
# Oslo              9.8                Norway               Europe    59.9111
# Copenhagen        8.5               Denmark               Europe    55.6786
# Hong Kong         8.2             Hong Kong       Asia & Pacific    22.3050
# Singapore         8.1             Singapore       Asia & Pacific     1.3000
# Manhattan         7.7         United States        North America    40.7834
# Paris             7.5                France               Europe    48.8566
# San Francisco     7.2         United States        North America    37.7562
# Boston            7.2         United States        North America    42.3188
# Helsinki          7.1               Finland               Europe    60.1756
# Zurich            7.1           Switzerland               Europe    47.3786
# ...
